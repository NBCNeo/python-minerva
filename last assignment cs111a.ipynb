# %%
polygon([(0,0), (2,2), (2,0)], color = 'red', alpha = 0.5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x y')
capacity = 100
growth_rate = 0.5 # population increases by 70% per unit of time
plot_slope_field(growth_rate * (1-y/capacity) * y, (x,0,5), (y,-100,capacity*2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y = var('x y')
F(x) = (251*e^(0.01*x)-250)/0.01
plot_slope_field(0.01 * y + 250, (x,0,12), (y,0,5000))+plot((251*e^(0.01*x)-250)/0.01,(x,0,12))+point((0,F(0)), color='green', size=40)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
x,y = var('x y')
capacity = 100
growth_rate = 0.5 # population increases by 70% per unit of time
fishing = 5
plot_slope_field(growth_rate * (1-y/capacity) * y - fishing, (x,0,5), (y,-100,capacity*2))
# Out:
# Graphics object consisting of 1 graphics primitive
